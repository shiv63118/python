# %%
class Student:
    pass

s1 = Student()

print(s1)

# %%
class Student:
    def __init__(self):
        print("Constructor is called")

s1 = Student()
# Out:
# Constructor is called

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

s1 = Student("Shiv", 19)

print(s1.name)
print(s1.age)
# Out:
# Shiv
# 19

# %%
class Student:
    def __init__(self, name):
        self.name = name

s1 = Student("Rahul")
s2 = Student("Amit")

print(s1.name)
print(s2.name)
# Out:
# Rahul
# Amit

# %%
class Student:
    def __init__(self, name):
        self.name = name

    def display(self):
        print("Student Name:", self.name)

s1 = Student("Shiv")
s1.display()
# Out:
# Student Name: Shiv

# %%
class Student:
    def __init__(self, name):
        self.name = name

    def display(self):
        print(self.name)

s1 = Student("Shiv")
s2 = Student("Rahul")
s3 = Student("Amit")

s1.display()
s2.display()
s3.display()
# Out:
# Shiv
# Rahul
# Amit

# %%
class Student:
    def __init__(self):
        self.name = "Unknown"

s1 = Student()

print(s1.name)
# Out:
# Unknown

# %%
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

s1 = Student("Shiv", 95)

print(s1.name)
print(s1.marks)
# Out:
# Shiv
# 95

# %%
class Student:
    def __init__(self, *args):
        print(args)

Student()
Student("Shiv")
Student("Shiv", 19)
Student("Shiv", 19, 95)
# Out:
# ()
# ('Shiv',)
# ('Shiv', 19)
# ('Shiv', 19, 95)

# %%
class Student:
    def __init__(self, *args):
        if len(args) == 0:
            print("No data")
        elif len(args) == 1:
            self.name = args[0]
            print("Name:", self.name)
        elif len(args) == 2:
            self.name = args[0]
            self.age = args[1]
            print(self.name, self.age)

Student()
Student("Shiv")
Student("Shiv", 19)
# Out:
# No data
# Name: Shiv
# Shiv 19

# %%
class Student:
    school = "IIT Patna"

    def __init__(self, name):
        self.name = name

s1 = Student("Shiv")
s2 = Student("Rahul")

print(s1.school)
print(s2.school)
# Out:
# IIT Patna
# IIT Patna

# %%
class Student:
    school = "IIT Patna"

Student.school = "MIT"

print(Student.school)
# Out:
# MIT

# %%
class Student:

    @staticmethod
    def greet():
        print("Welcome Students")

Student.greet()
# Out:
# Welcome Students

# %%
class Student:
    school = "IIT Patna"

    @classmethod
    def change_school(cls, new_name):
        cls.school = new_name

Student.change_school("NIT Patna")

print(Student.school)
# Out:
# NIT Patna

# %%
class Student:
    def __init__(self):
        self.name = "Shiv"

s1 = Student()

print(s1.name)
# Out:
# Shiv

# %%
class Student:
    def __init__(self):
        self._name = "Shiv"

s1 = Student()

print(s1._name)
# Out:
# Shiv

# %%
class Student:
    def __init__(self):
        self.__name = "Shiv"

    def show(self):
        print(self.__name)

s1 = Student()
s1.show()
# Out:
# Shiv

# %%
class Student():
    college = 'iitp'
    name = "anonymous"
    def __init__(self,name,marks):
        self.name = name
        self.marks = marks
        print("adding new student in database..")

    def welcome(self):
        print("welcome student,", self.name)

    def get_marks(self):
        return self.marks




s1 = Student("shiv", 88)
print(s1.name,s1.marks,s1.college)
# s2 = Student("shiv",85)
# print(s2.name, s2.marks, s2.college)
# print(Student.college)      #another way to print class attribute
s1.welcome()    
print(s1.get_marks())
# Out:
# adding new student in database..
# shiv 88 iitp
# welcome student, shiv
# 88

# %%
class Car:
    color = "blue"
    brand = "mercedes"

car1 = Car()
print(car1.color)
print(car1.brand)
# Out:
# blue
# mercedes

# %%
class car:
    def __init__(self, brand, color):
        self.brand = brand
        self.color = color
    
    def show(self):
        print(f"car brand: {self.brand} \ncolor : {self.color}\n")


c1 = car("fortuner","black")
c2 = car("tesla","red")

c1.show()
c2.show()
# Out:
# car brand: fortuner
# color : black
#
# car brand: tesla
# color : red

# %%
class vehicle(car):
    def run(self):
        print("All vehicles run!")

v1 = vehicle("bmw","black")

v1.show()
v1.run()
# Out:
# car brand: bmw
# color : black
#
# All vehicles run!

# %%
print("hello world")
# Out:
# hello world

# %%
class Account:
    def __init__(self,balance,acc_nu):
        self.balance = balance
        self.acc_nu = acc_nu

    def credit(self,amount):
        self.balance += amount
        print(f"amount {amount} has been credited to your account {self.acc_nu}")
        print(f"now your total balance is {self.total_balance()}")

    def debit(self,amount):
        self.balance -= amount
        print(f"amount {amount} has been debited from your account {self.acc_nu}")
        print(f"now your total balance is {self.total_balance()}")

    def total_balance(self):
        return self.balance

a1 = Account(10000, 12345)

a1.credit(1000)
a1.debit(11000)
a1.credit(150000)
# Out:
# amount 1000 has been credited to your account 12345
# now your total balance is 11000
# amount 11000 has been debited from your account 12345
# now your total balance is 0
# amount 150000 has been credited to your account 12345
# now your total balance is 150000

# %%
def ram():
    global sell
    sell = 9

# ram.shiv = 6
# print(ram.shiv)
# print()
print(sell)
# Out:
# 9

# %%
for i in range(-8,9,1):
    if i== 0:
           continue
    for j in range(abs(i)):
       
            
        print("*",end=" ")
    print()
# Out:
# * * * * * * * *
# * * * * * * *
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * * * *
# * * * * * * * *

# %%
class Student:
    name = "karan"
    
    
s1 = Student()
print(s1.name)
s2 = Student()
print(s2.name)
# Out:
# karan
# karan

# %%
class Car:
    color = "blue"
    brand = "mercedes"
    
car1 = Car()
print(car1.color)
print(car1.brand)
# Out:
# blue
# mercedes

# %%
#constructor

class Student:
    #default constructors
    def __init__(self):
        print(default)
        
     #parameterized constructors
    def __init__(self, name, marks):
        self.name = name 
        self.marks = marks
        print("adding new students in Database..")
    
s1 = Student("karan", 90)
print(s1.name, s1.marks)  #karan

s2 = Student("arjun", 92)
print(s2.name, s2.marks)   #arjun

# s3 = Student()
# Out:
# adding new students in Database..
# karan 90
# adding new students in Database..
# arjun 92

# %%
class Student:
    def __init__(self, *args):
        print(args)

Student()
Student("Shiv")
Student("Shiv", 19)
Student("Shiv", 19, 95)
# Out:
# ()
# ('Shiv',)
# ('Shiv', 19)
# ('Shiv', 19, 95)
