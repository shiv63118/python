# %%
# 2D arrays  ==  matrix
arr_2d = np.array([
    [1,2,3,],
    [4,5,6],            #rows & columns
    [7,8,9]
])
print(arr_2d)

# %%
list = [1,2,3,4,5]
arr=np.array(list)
print(arr)

# %%
zeros_array = np.zeros((8,3))
print(zeros_array)

# %%
ones_array = np.ones((2,3))
print(ones_array)
